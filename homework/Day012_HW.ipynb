# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 取出今天所有的發文
# * ② 如果想要依照類別分類，怎麼儲存會比較好？
# * ③ 哪一個類別的文章最多

# %% [markdown]
# ### ① 取出今天所有的發文

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url='https://www.ettoday.net/news/news-list.htm'
r=requests.get(url)

soup=BeautifulSoup(r.text, "html5lib")
words=[]
for d in soup.find(class_="part_list_2").find_all('h3'):
    print(d.find(class_="date").text, d.find_all('a')[-1].text)
    words.append([d.find(class_="date").text,d.find('em').text,d.find_all('a')[-1].text])
# Out:
# 2020/02/13 06:39 陸男帶空行李箱赴日買口罩　關西機場被逮跳針掰「熟人拜託」
# 2020/02/13 06:22 2020代表色不是只有經典藍！快背上時髦的「番紅花黃」出門吧
# 2020/02/13 06:18 WHO：預測武漢肺炎高峰和結束還太早　應抱持「極度謹慎」態度
# 2020/02/13 06:06 2縣市大雨特報！全台午後變天一張圖曝5天雨區　下波直逼寒流凍5天探8度
# 2020/02/13 06:05 WHO把台灣算在中國疫區內　歐洲多國議員聯名要求秘書長更正
# 2020/02/13 06:00 LIVE／台灣第一枚太空火箭發射倒數　「飛鼠一號」台東南田升空
# 2020/02/13 05:50 外交部：台灣獲美邀請　成國際宗教自由聯盟觀察員
# 2020/02/13 05:49 擔心武漢肺炎MWC 2020宣布取消　11家大廠退出150億商機蒸發
# 2020/02/13 05:38 倫敦首例武漢肺炎確診「患者在中國染病」　全英累計9例
# 2020/02/13 05:07 維基百科之亂　從茱蒂嘉蘭「被改名」談起
# 2020/02/13 03:18 嫌醫院供餐差！病人想吃泡麵「三餐摔飯菜」　女護師崩潰：40歲巨嬰怎哄
# 2020/02/13 03:13 半路放生30重症病患！北京震怒開鍘　武昌政府赴醫院向他們「親自道歉」
# 2020/02/13 02:44 菲律賓對台禁令！我擁5項強力反擊　恐衝擊在台15萬菲工
# 2020/02/13 02:41 台灣負壓隔離病房「1100間」超厲害　王定宇曝真相：贏過日本
# 2020/02/13 02:17 男偶像「破格露肚裝」胸下倒V型全敞開！　六塊腹肌、馬甲線露出⋯網驚呆
# 2020/02/13 02:14 情人節最強情歌是這首「2013神曲」！　閃光日每年點擊數都上升50%
# 2020/02/13 01:52 「15家口罩廠商」出爐！經濟部公布60條產線　一張表看3大廠分最多
# 2020/02/13 01:35 好市多酒精棉片上架　3大原因網友瘋狂呼籲「不要買」
# 2020/02/13 01:12 柬埔寨同意郵輪靠港！　威士特丹號「1455名人球」可以回家了
# 2020/02/13 01:11 水象星座注意！2020第一波水逆來襲　雙魚別淪為小三
# ...

# %% [markdown]
# ### ② 如果想要依照類別分類，怎麼儲存會比較好？

# %%
'''
Your Code
'''
columns=['日期','類別','標題']

table=pd.DataFrame(words,columns=columns)
table
# Out:
#                   日期  類別                                   標題
# 0   2020/02/13 06:39  國際         陸男帶空行李箱赴日買口罩　關西機場被逮跳針掰「熟人拜託」
# 1   2020/02/13 06:22  時尚       2020代表色不是只有經典藍！快背上時髦的「番紅花黃」出門吧
# 2   2020/02/13 06:18  國際       WHO：預測武漢肺炎高峰和結束還太早　應抱持「極度謹慎」態度
# 3   2020/02/13 06:06  生活  2縣市大雨特報！全台午後變天一張圖曝5天雨區　下波直逼寒流凍5天探8度
# 4   2020/02/13 06:05  國際        WHO把台灣算在中國疫區內　歐洲多國議員聯名要求秘書長更正
# ..               ...  ..                                  ...
# 95  2020/02/12 20:37  軍武       直擊發射／台灣首枚民間自製火箭「飛鼠一號」　台東南田基地曝光
# 96  2020/02/12 20:37  影劇    「跪坐焦屍、王水溶屍」命案死狀駭人　許瑋甯《誰是被害者》破台劇尺度
# 97  2020/02/12 20:36  影劇   歐陽靖點出日本防疫多漏洞！　機場檢疫鬆散「陸人不用檢測就可直接入關」
# 98  2020/02/12 20:36  影劇         女星「激吻温貞菱」被肉搜　撞臉周冬雨開心喊：是我的榮幸！
# 99  2020/02/12 20:31  國際    菲律賓議員質詢突破盲腸　43比18「你禁台灣不禁新加坡？」嗆爆官員
#
# [100 rows x 3 columns]

# %% [markdown]
# ### ③ 哪一個類別的文章最多

# %%
'''
Your Code
'''

group=table.groupby('類別')
table2=pd.DataFrame(group.size(),columns=['文章數量'])
table2.sort_values(by = '文章數量',ascending=False)
# Out:
#       文章數量
# 類別
# 影劇      25
# 國際      15
# 時尚       9
# 政治       9
# 生活       8
# 大陸       6
# 地方       4
# 3C家電     3
# 財經       3
# 社會       3
# 體育       3
# 寵物動物     3
# 健康       3
# 保險       2
# 網搜       1
# 親子       1
# 軍武       1
# 旅遊       1
