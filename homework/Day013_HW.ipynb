# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url='https://www.ptt.cc/bbs/NBA/index.html'
r=requests.get(url)
soup=BeautifulSoup(r.text,'html5lib')

for d in soup.find_all(class_="title"):
    print('標題:'+d.text.replace('\t','').replace('\n',''))
    try:
        r=BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text,"html5lib")
        print('作者:'+r.find(class_='article-meta-value').text)
        print('時間:'+r.find(class_='article-meta-tag',string="時間").next_sibling.string)
    except:
        continue
# Out:
# 標題:[外絮] Perkins: 每次想到KI那傢伙，我就想吐
# 作者:SupHateSpurs (好人)
# 時間:Wed Feb 12 18:44:07 2020
# 標題:[情報] PG:76人有著一些主場優勢
# 作者:justgetup (gonna fight)
# 時間:Wed Feb 12 19:45:06 2020
# 標題:[討論] 為什麼沒人覺得現在哨音變比較少？
# 作者:asd831129 (追追熊)
# 時間:Wed Feb 12 20:14:13 2020
# 標題:[新聞] 重磅交易被質疑　勇士老闆回應：威金斯
# 作者:asdf1256 (guest)
# 時間:Wed Feb 12 20:39:07 2020
# 標題:(本文已被刪除) [Wojnarowski]
# 標題:(已被Vedan刪除) <ilanese>1-1(150)
# 標題:Re: [討論] 為什麼以前的NBA比較好看
# 作者:dkl1027 (凱文)
# 時間:Wed Feb 12 21:18:52 2020
# 標題:[情報] Isaiah Thomas, Dion Waiters 正式成為FA
# 作者:thnlkj0665 (灰色地帶)
# 時間:Wed Feb 12 21:36:07 2020
# 標題:[討論] Re: [討論] 為什麼沒人覺得現在哨音變比較少？
# 作者:akirachen100 (米分虫工王求)
# 時間:Wed Feb 12 21:48:20 2020
# 標題:Re: [討論] 為什麼沒人覺得現在哨音變比較少？
# 作者:gg8n8nd34ss (cat)
# 時間:Wed Feb 12 22:07:01 2020
# 標題:Re: [討論] 為什麼沒人覺得現在哨音變比較少？
# 作者:driftcreator (北美漂流中)
# 時間:Wed Feb 12 22:08:56 2020
# 標題:[討論] 有可能把規則改得適合機器輔助判決嗎？
# 作者:goldenrose (蓋世英雄)
# 時間:Wed Feb 12 22:58:50 2020
# 標題:[新聞] 全明星賽尚未獲邀約 老鷹主帥替卡特抱屈
# 作者:Gotham (萬惡之城)
# 時間:Wed Feb 12 23:59:20 2020
# 標題:Re: [討論] 為什麼沒人覺得現在哨音變比較少？
# 作者:moodoa3583 (金牌台灣啤酒)
# 時間:Thu Feb 13 00:52:30 2020
# 標題:[花邊] 西門賽前練習連續命中8顆三分
# 作者:nwd4e9cd (冒泡泡~泡泡！)
# 時間:Thu Feb 13 01:07:26 2020
# 標題:[新聞] 雙MVP發威 哈登：會很可怕
# 作者:bmw300811 (王傑在一起)
# 時間:Thu Feb 13 01:13:53 2020
# 標題:Re: [討論] 為什麼以前的NBA比較好看
# 作者:JRSmith (臭酸肥宅)
# 時間:Thu Feb 13 06:23:12 2020
# 標題:[討論]96梯與03梯選秀，不過是沾時代便宜而已
# 作者:cidexin (月娥)
# 時間:Thu Feb 13 06:26:23 2020
# 標題:[公告] 板規v6.8
# 標題:[公告] 樂透取消及未來不再開啟樂透
# 作者:Vedan (味丹)
# 時間:Mon Jun 24 15:08:02 2019
# 標題:[公告] 版主上任相關事項
# 作者:qazwsx879345 (Rajon Rondo)
# 時間:Fri Oct 25 10:44:03 2019
# 標題:[情報] SEASON Schedule 賽程 February 19–20
# 作者:Acetoxy (阿斯)
# 時間:Fri Jan 31 22:36:43 2020

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''

# 2nd way
for d in soup.find_all(class_="r-ent"):
    print('標題： ', d.find(class_='title').text.replace('\t', '').replace('\n', ''))
    print('作者： ', d.find(class_='author').text.replace('\t', '').replace('\n', ''))
    print('時間： ', d.find(class_='date').text.replace('\t', '').replace('\n', ''))
# Out:
# 標題：  [外絮] Perkins: 每次想到KI那傢伙，我就想吐
# 作者：  SupHateSpurs
# 時間：   2/12
# 標題：  [情報] PG:76人有著一些主場優勢
# 作者：  justgetup
# 時間：   2/12
# 標題：  [討論] 為什麼沒人覺得現在哨音變比較少？
# 作者：  asd831129
# 時間：   2/12
# 標題：  [新聞] 重磅交易被質疑　勇士老闆回應：威金斯
# 作者：  asdf1256
# 時間：   2/12
# 標題：  (本文已被刪除) [Wojnarowski]
# 作者：  -
# 時間：   2/12
# 標題：  (已被Vedan刪除) <ilanese>1-1(150)
# 作者：  -
# 時間：   2/12
# 標題：  Re: [討論] 為什麼以前的NBA比較好看
# 作者：  dkl1027
# 時間：   2/12
# 標題：  [情報] Isaiah Thomas, Dion Waiters 正式成為FA
# 作者：  thnlkj0665
# 時間：   2/12
# 標題：  [討論] Re: [討論] 為什麼沒人覺得現在哨音變比較少？
# 作者：  akirachen100
# 時間：   2/12
# 標題：  Re: [討論] 為什麼沒人覺得現在哨音變比較少？
# 作者：  gg8n8nd34ss
# 時間：   2/12
# 標題：  Re: [討論] 為什麼沒人覺得現在哨音變比較少？
# 作者：  driftcreator
# 時間：   2/12
# 標題：  [討論] 有可能把規則改得適合機器輔助判決嗎？
# 作者：  goldenrose
# 時間：   2/12
# 標題：  [新聞] 全明星賽尚未獲邀約 老鷹主帥替卡特抱屈
# 作者：  Gotham
# 時間：   2/12
# 標題：  Re: [討論] 為什麼沒人覺得現在哨音變比較少？
# 作者：  moodoa3583
# 時間：   2/13
# 標題：  [花邊] 西門賽前練習連續命中8顆三分
# 作者：  nwd4e9cd
# 時間：   2/13
# 標題：  [新聞] 雙MVP發威 哈登：會很可怕
# 作者：  bmw300811
# 時間：   2/13
# 標題：  Re: [討論] 為什麼以前的NBA比較好看
# 作者：  JRSmith
# 時間：   2/13
# 標題：  [討論]96梯與03梯選秀，不過是沾時代便宜而已
# 作者：  cidexin
# 時間：   2/13
# 標題：  [公告] 板規v6.8
# 作者：  Vedan
# 時間：   5/24
# 標題：  [公告] 樂透取消及未來不再開啟樂透
# 作者：  Vedan
# 時間：   6/24
# 標題：  [公告] 版主上任相關事項
# 作者：  qazwsx879345
# 時間：  10/25
# 標題：  [情報] SEASON Schedule 賽程 February 19–20
# 作者：  Acetoxy
# 時間：   1/31

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/WNBA/index53.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html5lib')

for d in soup.find_all(class_="title"):
    print('標題: ' + d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc' + d.find('a')['href']).text, "html5lib")
        print('作者: ' + r.find(class_ = 'article-meta-value').text)
        print('時間: ' + r.find(class_ = 'article-meta-tag', string = "時間").next_sibling.string)

    except:
        continue
# Out:
# 標題: [情報] WNBA季後賽第一輪
# 作者: cobras638 ()
# 時間: Thu Aug 23 08:02:28 2018
# 標題: [情報] WNBA季後賽第二輪
# 作者: cobras638 ()
# 時間: Sun Aug 26 01:11:36 2018
# 標題: [情報] WNBA季後賽第三輪
# 作者: cobras638 ()
# 時間: Sat Sep  8 22:20:22 2018
# 標題: [情報] 2018 WNBAFINALS
# 作者: cobras638 ()
# 時間: Sat Sep 15 09:32:26 2018
# 標題: [情報] Chicago Sky Unveil New Logo
# 作者: cobras638 ()
# 時間: Sat Dec 15 10:30:01 2018
# 標題: [情報] James Wade Named General Manager and
# 作者: cobras638 ()
# 時間: Sat Dec 15 10:34:00 2018
# 標題: [情報] 2019 Core Players, Reserved Players,
# 作者: cobras638 ()
# 時間: Thu Jan 17 14:10:47 2019
# 標題: [情報] 2019 WNBA選秀結果
# 作者: cobras638 ()
# 時間: Fri Apr 12 14:34:31 2019
# 標題: [情報] 2019WNBA例行賽賽程
# 作者: cobras638 ()
# 時間: Tue May 14 13:22:08 2019
# 標題: [情報] 2019戰績(至美國時間6/13)
# 作者: cobras638 ()
# 時間: Fri Jun 14 16:14:12 2019
# 標題: [情報] 2019戰績(至美國時間7/3)
# 作者: cobras638 ()
# 時間: Thu Jul  4 16:59:20 2019
# 標題: [情報] 2019戰績(至美國時間7/17)
# 作者: cobras638 ()
# 時間: Thu Jul 18 16:29:11 2019
# 標題: [問題] 請問大家都是如何看轉播？
# 作者: iloveaudi (凱)
# 時間: Mon Jul 29 01:58:05 2019
# 標題: [情報] 2019戰績(至美國時間8/9)
# 作者: cobras638 ()
# 時間: Sat Aug 10 16:59:44 2019
# 標題: [情報] 2019戰績(至美國時間8/22)
# 作者: cobras638 (旺來西瓜仙拚仙)
# 時間: Fri Aug 23 19:23:44 2019
# 標題: [情報] 2019戰績(至美國時間8/30)
# 作者: cobras638 (旺來西瓜仙拚仙)
# 時間: Sat Aug 31 22:43:41 2019
# 標題: [情報] 2019 WNBA季後賽日程
# 作者: cobras638 (旺來西瓜仙拚仙)
# 時間: Fri Sep  6 20:49:34 2019
# 標題: [情報] 2019WNBA例賽最終戰績
# 作者: cobras638 (幸福冠軍到 HIHI送夠夠)
# 時間: Mon Sep  9 21:03:09 2019
# 標題: [情報] 2019WNBA季後賽第一輪
# 作者: cobras638 (幸福冠軍到 HIHI送夠夠)
# 時間: Fri Sep 13 16:56:18 2019
# 標題: [情報] 2019WNBA季後賽第二輪
# 作者: cobras638 (旺來西瓜仙拚仙)
# 時間: Mon Sep 16 17:39:15 2019
